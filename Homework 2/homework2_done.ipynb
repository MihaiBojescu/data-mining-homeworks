# %% [markdown]
# # Homework 2 - association rules
#
# In this homework we will perform association between data series in the obesity dataset. For this notebook we will use the following formulas:
#
# $$
# \begin{align*}
#     support(X) &= P(X) \\
#             &= \frac{\text{number of instances containing X in the dataset}}{\text{total number of items in the dataset}} \\
#     \\
#     support(X \rightarrow Y) &= P(X \cap Y) \\
#                             &= support(X \cup Y) \\
#                             &= \frac{\text{number of instances containing both X and Y in the dataset}}{\text{total number of items in the dataset}} \\
#     \\
#     confidence(X \rightarrow Y) &= P(Y|X) = \frac{P(X \cap Y)}{P(X)} \\
#                                 &= \frac{support(X \cup Y)}{support(X)} \\
#     \\
#     lift(X \rightarrow Y) &= \frac{P(X \cap Y)}{P(X) \cdot P(Y)} \\
#                           &= \frac{support(X \cup Y)}{support(X) \cdot support(Y)} \\
#     \\
#     conviction(X \rightarrow Y) &= \frac{1 - P(Y)}{1 - P(Y|X)} = \frac{1 - P(Y)}{1 - \frac{P(X \cap Y)}{P(X)}} \\
#                                 &= \frac{1 - support(Y)}{1 - confidence(X \rightarrow Y)} \\
# \end{align*}
# $$
#
# We will use the Apriori and ECLAT algorithms.

# %% [markdown]
# ## Conclusions
#
# TBD, need to update.

# %% [markdown]
# ## Dependencies

# %% [markdown]
# ### General dependencies
#
# Imports for Python

# %%
import copy
import os
os.environ['R_HOME'] = 'C:\Program Files\R\R-4.3.3'

# %%
import typing as t
import csv
import numpy as np
import numpy.typing as npt
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import HTML

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import arulespy.arules as arules
import arulespy.arulesViz as arulesviz

# %%
import seaborn as sns
from catscatter import catscatter

# %% [markdown]
# ### Dataset-specific dependencies
#
# Dataset manager, known labels, known outputs for the dataset.

# %%
LABEL_VARIABLE = "NObeyesdad"
NUMERICAL_VARIABLES = ["Age", "Height", "Weight", "FCVC", "NCP", "CH2O", "FAF", "TUE"]
CATEGORICAL_VARIABLES_NO_LABEL = [
    "FAVC",
    "CAEC",
    "CALC",
    "SCC",
    "MTRANS",
    "Gender",
    "family_history_with_overweight",
    "SMOKE",
]
CATEGORICAL_VARIABLES = [
    *CATEGORICAL_VARIABLES_NO_LABEL,
    LABEL_VARIABLE,
]
ALL_VARIABLES_NO_LABEL = [*NUMERICAL_VARIABLES, *CATEGORICAL_VARIABLES_NO_LABEL]
ALL_VARIABLES = [*NUMERICAL_VARIABLES, *CATEGORICAL_VARIABLES]
LABEL_DICTIONARY = {
    "Age": "Age",
    "Height": "Height (cm)",
    "Weight": "Weight (kg)",
    "FCVC": " Frequency of consumption of vegetables (times per day)",
    "NCP": "Number of main meals",
    "CH2O": "Consumption of water daily (Liters)",
    "FAF": "Physical activity frequency (times per day)",
    "TUE": "Time using technology devices (hours)",
    "FAVC": "Frequent consumption of high caloric food",
    "CAEC": "Consumption of food between meals",
    "CALC": "Consumption of alcohol",
    "SCC": "Calories consumption monitoring",
    "MTRANS": "Transportation used",
    "Gender": "Gender",
    "family_history_with_overweight": "Family member suffered or suffers from overweight",
    "SMOKE": "Smoker or not",
    "NObeyesdad": "Obesity level",
}

T = t.TypeVar("T")


class Person:
    Gender: str
    Age: np.int32
    Height: np.float32
    Weight: np.float32
    family_history_with_overweight: str
    FAVC: str
    FCVC: np.float32
    NCP: np.float32
    CAEC: str
    SMOKE: str
    CH2O: np.float32
    SCC: str
    FAF: np.float32
    TUE: np.float32
    CALC: str
    MTRANS: str
    NObeyesdad: str

    def __init__(
        self,
        Gender: str,
        Age: str,
        Height: str,
        Weight: str,
        family_history_with_overweight: str,
        FAVC: str,
        FCVC: str,
        NCP: str,
        CAEC: str,
        SMOKE: str,
        CH2O: str,
        SCC: str,
        FAF: str,
        TUE: str,
        CALC: str,
        MTRANS: str,
        NObeyesdad: str,
    ):
        self.Gender = Gender
        self.Age = np.float32(Age)
        self.Height = np.float32(Height)
        self.Weight = np.float32(Weight)
        self.family_history_with_overweight = family_history_with_overweight
        self.FAVC = FAVC
        self.FCVC = np.float32(FCVC)
        self.NCP = np.float32(NCP)
        self.CAEC = CAEC
        self.SMOKE = SMOKE
        self.CH2O = np.float32(CH2O)
        self.SCC = SCC
        self.FAF = np.float32(FAF)
        self.TUE = np.float32(TUE)
        self.CALC = CALC
        self.MTRANS = MTRANS
        self.NObeyesdad = NObeyesdad

    def __str__(self):
        return vars(self)

    def __len__(self):
        return len(vars(self))

    def __repr__(self):
        return vars(self)


class DatasetManager:
    def __init__(self, path_to_csv: str):
        self.path_to_csv = path_to_csv

    def load_as_obj_list(self) -> list[Person]:
        with open(self.path_to_csv) as csv_file:
            csv_reader = csv.DictReader(csv_file)
            return [Person(**row) for row in csv_reader]

# %%
dataset_manager = DatasetManager("data/ObesityDataSet.csv")
dataset_obj_list = dataset_manager.load_as_obj_list()
dataset_dataframe = pd.DataFrame.from_records(
    data=[vars(entry) for entry in dataset_obj_list]
)

# %% [markdown]
# ### Categorial data utility functions
#
# Here we add utility functions (if any) for the categorial data types.

# %%
# TODO: add if any are found

# %% [markdown]
# ### Continuous data utility functions
#
# Here we add utility functions (if any) for the continuous data types.

# %%
def get_np_bins_and_labels(bins: list[tuple[float, float]]) -> tuple[np.array, list[str]]:
    return np.array(np.array(bins).T[0].tolist() + [bins[-1][1]]).astype(np.float32), [f"({lh}, {rh}]" for lh, rh in bins]


predifined_bins = {
    "Age": get_np_bins_and_labels([
        (0, 12),
        (12, 18),
        (18, 26),
        (26, 36),
        (36, 46),
        (46, 60),
        (60, 200)
    ]),
    "Weight": get_np_bins_and_labels([
        (0, 55),
        (55, 70),
        (70, 80),
        (80, 100),
        (100, 120),
        (120, 400)
    ]),
    "Height": get_np_bins_and_labels([
        (0, 1.62),
        (1.62, 1.75),
        (1.75, 3.00)
    ])
}

def bin_numerical_equally_by_frequency(
    data: t.Union[npt.NDArray[np.float32], npt.NDArray[np.int32]], bins: int = 30
):
    """
    Performs roughly equal binning based on the frequency of the items.
    Example: For data = [1, 2, 3, 4, 5, 6, 7, 8, 9] and bins = 3, result will be (1, 3], (3, 6], (6, 9]
    """

    if type(data[0]) is not np.float32 and type(data[0]) is not np.int32:
        return data

    result = pd.qcut(data, q=bins, duplicates="drop").astype("string")
    return result

def bin_on_predefined_way(data: t.Union[npt.NDArray[np.float32], npt.NDArray[np.int32]], predefined_bins: tuple[np.array, list[str]]):

    if type(data[0]) is not np.float32 and type(data[0]) is not np.int32:
        return data

    return pd.cut(data, bins=predefined_bins[0], labels=predefined_bins[1], include_lowest=True)

def bin_numerical_smartly(data_name: str, data: t.Union[npt.NDArray[np.float32], npt.NDArray[np.int32]], bins: int = 30):

    if data_name not in predifined_bins:
        return bin_numerical_equally_by_frequency(data, bins=bins)
    else:
        return bin_on_predefined_way(data, predifined_bins[data_name])

# %% [markdown]
# ### Algorithm utility functions
#
# Here we add utility functions for the algorithms to help us reduce code duplication.

# %%
def run_apriori(
    transactions: arules.ro.DataFrame, support: float, confidence: float
) -> t.Optional[pd.DataFrame]:
    try:
        rules = arules.apriori(
            transactions,
            parameter=arules.parameters({"supp": support, "conf": confidence}),
            control=arules.parameters({"verbose": False}),
        )
        return rules.as_df()
    except:
        return None


def run_apriori_build_html(
    transactions: arules.ro.DataFrame, support: float, confidence: float
) -> tuple[str, pd.DataFrame]:
    result = ""

    rules_dataframe = run_apriori(
        transactions=transactions, support=support, confidence=confidence
    )

    result += f"<h2>Result for Apriori run (support: {support}, confidence: {confidence})</h2>"
    result += (
        rules_dataframe.to_html()
        if rules_dataframe is not None
        else "<p>No rules were found</p>"
    )
    result += "</br>"

    return result, rules_dataframe


def run_eclat(
    transactions: arules.ro.DataFrame, support: float, confidence: float
) -> t.Optional[pd.DataFrame]:
    try:
        rules = arules.eclat(
            transactions,
            parameter=arules.parameters({"supp": support}),
            control=arules.parameters({"verbose": False}),
        )
        return rules.as_df()
    except:
        return None


def run_eclat_build_html(
    transactions: arules.ro.DataFrame, support: float, confidence: float
) -> tuple[str, pd.DataFrame]:
    result = ""

    rules_dataframe = run_eclat(
        transactions=transactions, support=support, confidence=confidence
    )

    result += f"<h2>Result for ECLAT run (support: {support})</h2>"
    result += (
        rules_dataframe.to_html()
        if rules_dataframe is not None
        else "<p>No rules were found</p>"
    )
    result += "</br>"

    return result, rules_dataframe

def data_frame_to_html(title: str, data_frame: pd.DataFrame) -> str:
    return f"<h2>{title}</h2></br>{data_frame.to_html()}</br>"

# %% [markdown]
# ## Preliminary data analysis
#
# Here we built plots for the data. Mostly for debugging purposes.

# %%
for label in CATEGORICAL_VARIABLES_NO_LABEL:
    pretty_label = LABEL_DICTIONARY[label]
    dataset_subset_dataframe = dataset_dataframe[label].astype(str)

    plt.figure()
    plt.hist(dataset_subset_dataframe)
    plt.xlabel(pretty_label)
    plt.ylabel("Count")
    plt.show()

# %%
for label in NUMERICAL_VARIABLES:
    pretty_label = LABEL_DICTIONARY[label]
    dataset_subset_dataframe = dataset_dataframe[label].astype(np.float32)
    binned_data = bin_numerical_smartly(
        data_name=label,
        data=dataset_subset_dataframe, bins=10
    )

    plt.figure()
    binned_data.value_counts().plot(kind="bar", xlabel=label, ylabel="Count", rot=90)
    plt.xlabel(pretty_label)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## Finding association rules
#
# Here we use the `arules` library to find association rules.

# %% [markdown]
# ### Categorical - categorical associations with Apriori algorithm

# %%
parameters = [
    (0.7, 0.4),
    (0.8, 0.8),
    (0.9, 0.8),
    (0.9, 0.9),
    (0.95, 0.9),
    (0.95, 0.95),
]

dataset_subset_dataframe = dataset_dataframe[CATEGORICAL_VARIABLES]
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
categorical_categorical_apriori = {}

for support, confidence in parameters:
    html_out, df_out = run_apriori_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    categorical_categorical_apriori[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for Apriori run (support: 0.7, confidence: 0.4)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{}</td>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.748460</td>
#       <td>0.748460</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{}</td>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.817622</td>
#       <td>0.817622</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1726</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.836097</td>
#       <td>0.836097</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1765</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.883941</td>
#       <td>0.883941</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1866</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{}</td>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>0.954524</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>0.979157</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>{SCC=no}</td>
#       <td>0.713406</td>
#       <td>0.953165</td>
#       <td>0.748460</td>
#       <td>0.998576</td>
#       <td>1506</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{SCC=no}</td>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.713406</td>
#       <td>0.747395</td>
#       <td>0.954524</td>
#       <td>0.998576</td>
#       <td>1506</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.734249</td>
#       <td>0.981013</td>
#       <td>0.748460</td>
#       <td>1.001895</td>
#       <td>1550</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{SMOKE=no}</td>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.734249</td>
#       <td>0.749879</td>
#       <td>0.979157</td>
#       <td>1.001895</td>
#       <td>1550</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.732354</td>
#       <td>0.895713</td>
#       <td>0.817622</td>
#       <td>1.071303</td>
#       <td>1546</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.732354</td>
#       <td>0.875921</td>
#       <td>0.836097</td>
#       <td>1.071303</td>
#       <td>1546</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.748460</td>
#       <td>0.915411</td>
#       <td>0.817622</td>
#       <td>1.035602</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{FAVC=yes}</td>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.748460</td>
#       <td>0.846731</td>
#       <td>0.883941</td>
#       <td>1.035602</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{SCC=no}</td>
#       <td>0.795358</td>
#       <td>0.972769</td>
#       <td>0.817622</td>
#       <td>1.019115</td>
#       <td>1679</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{SCC=no}</td>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.795358</td>
#       <td>0.833251</td>
#       <td>0.954524</td>
#       <td>1.019115</td>
#       <td>1679</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.799621</td>
#       <td>0.977984</td>
#       <td>0.817622</td>
#       <td>0.998802</td>
#       <td>1688</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{SMOKE=no}</td>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.799621</td>
#       <td>0.816642</td>
#       <td>0.979157</td>
#       <td>0.998802</td>
#       <td>1688</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.761724</td>
#       <td>0.911048</td>
#       <td>0.836097</td>
#       <td>1.030666</td>
#       <td>1608</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{FAVC=yes}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.761724</td>
#       <td>0.861736</td>
#       <td>0.883941</td>
#       <td>1.030666</td>
#       <td>1608</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{SCC=no}</td>
#       <td>0.810516</td>
#       <td>0.969405</td>
#       <td>0.836097</td>
#       <td>1.015590</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{SCC=no}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.810516</td>
#       <td>0.849132</td>
#       <td>0.954524</td>
#       <td>1.015590</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.821412</td>
#       <td>0.982436</td>
#       <td>0.836097</td>
#       <td>1.003349</td>
#       <td>1734</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{SMOKE=no}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.821412</td>
#       <td>0.838897</td>
#       <td>0.979157</td>
#       <td>1.003349</td>
#       <td>1734</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>{FAVC=yes}</td>
#       <td>{SCC=no}</td>
#       <td>0.856466</td>
#       <td>0.968917</td>
#       <td>0.883941</td>
#       <td>1.015079</td>
#       <td>1808</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>{SCC=no}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.856466</td>
#       <td>0.897270</td>
#       <td>0.954524</td>
#       <td>1.015079</td>
#       <td>1808</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>{FAVC=yes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.867835</td>
#       <td>0.981779</td>
#       <td>0.883941</td>
#       <td>1.002678</td>
#       <td>1832</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>{SMOKE=no}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.867835</td>
#       <td>0.886309</td>
#       <td>0.979157</td>
#       <td>1.002678</td>
#       <td>1832</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>{SCC=no}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>0.980645</td>
#       <td>0.954524</td>
#       <td>1.001520</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>{SMOKE=no}</td>
#       <td>{SCC=no}</td>
#       <td>0.936049</td>
#       <td>0.955975</td>
#       <td>0.979157</td>
#       <td>1.001520</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>{SCC=no,MTRANS=Public_Transportation}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.701090</td>
#       <td>0.982736</td>
#       <td>0.713406</td>
#       <td>1.003655</td>
#       <td>1480</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>{MTRANS=Public_Transportation,SMOKE=no}</td>
#       <td>{SCC=no}</td>
#       <td>0.701090</td>
#       <td>0.954839</td>
#       <td>0.734249</td>
#       <td>1.000330</td>
#       <td>1480</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>{SCC=no,SMOKE=no}</td>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.701090</td>
#       <td>0.748988</td>
#       <td>0.936049</td>
#       <td>1.000705</td>
#       <td>1480</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>{CAEC=Sometimes,family_history_with_overweight=yes}</td>
#       <td>{SCC=no}</td>
#       <td>0.720512</td>
#       <td>0.983829</td>
#       <td>0.732354</td>
#       <td>1.030701</td>
#       <td>1521</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>{SCC=no,family_history_with_overweight=yes}</td>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.720512</td>
#       <td>0.905896</td>
#       <td>0.795358</td>
#       <td>1.083483</td>
#       <td>1521</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### Categorial - categorial associations with ECLAT algorithm

# %%
parameters = [
    (0.7, 0.4),
    (0.8, 0.8),
    (0.9, 0.8),
    (0.9, 0.9),
    (0.95, 0.9),
    (0.95, 0.95),
]

dataset_subset_dataframe = dataset_dataframe[CATEGORICAL_VARIABLES]
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
categorical_categorical_eclat = {}

for support, confidence in parameters:
    html_out, df_out = run_eclat_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    categorical_categorical_eclat[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for ECLAT run (support: 0.7)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{SCC=no,MTRANS=Public_Transportation,SMOKE=no}</td>
#       <td>0.701090</td>
#       <td>1480</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{MTRANS=Public_Transportation,SMOKE=no}</td>
#       <td>0.734249</td>
#       <td>1550</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{SCC=no,MTRANS=Public_Transportation}</td>
#       <td>0.713406</td>
#       <td>1506</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{CAEC=Sometimes,SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.708195</td>
#       <td>1495</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{CAEC=Sometimes,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.719090</td>
#       <td>1518</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{CAEC=Sometimes,SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.720512</td>
#       <td>1521</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{FAVC=yes,SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.721459</td>
#       <td>1523</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{FAVC=yes,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.734723</td>
#       <td>1551</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{FAVC=yes,SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.733775</td>
#       <td>1549</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.779725</td>
#       <td>1646</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.799621</td>
#       <td>1688</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.795358</td>
#       <td>1679</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{FAVC=yes,family_history_with_overweight=yes}</td>
#       <td>0.748460</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{CAEC=Sometimes,family_history_with_overweight=yes}</td>
#       <td>0.732354</td>
#       <td>1546</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{FAVC=yes,CAEC=Sometimes,SCC=no,SMOKE=no}</td>
#       <td>0.731407</td>
#       <td>1544</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{FAVC=yes,CAEC=Sometimes,SMOKE=no}</td>
#       <td>0.750829</td>
#       <td>1585</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{FAVC=yes,CAEC=Sometimes,SCC=no}</td>
#       <td>0.742302</td>
#       <td>1567</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{CAEC=Sometimes,SCC=no,SMOKE=no}</td>
#       <td>0.796779</td>
#       <td>1682</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{CAEC=Sometimes,SMOKE=no}</td>
#       <td>0.821412</td>
#       <td>1734</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{CAEC=Sometimes,SCC=no}</td>
#       <td>0.810516</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{FAVC=yes,CAEC=Sometimes}</td>
#       <td>0.761724</td>
#       <td>1608</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{FAVC=yes,SCC=no,SMOKE=no}</td>
#       <td>0.841781</td>
#       <td>1777</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{FAVC=yes,SMOKE=no}</td>
#       <td>0.867835</td>
#       <td>1832</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{FAVC=yes,SCC=no}</td>
#       <td>0.856466</td>
#       <td>1808</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>{SCC=no,SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>{FAVC=yes}</td>
#       <td>0.883941</td>
#       <td>1866</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.836097</td>
#       <td>1765</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.817622</td>
#       <td>1726</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.748460</td>
#       <td>1580</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.8)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{CAEC=Sometimes,SMOKE=no}</td>
#       <td>0.821412</td>
#       <td>1734</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{CAEC=Sometimes,SCC=no}</td>
#       <td>0.810516</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{FAVC=yes,SCC=no,SMOKE=no}</td>
#       <td>0.841781</td>
#       <td>1777</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{FAVC=yes,SMOKE=no}</td>
#       <td>0.867835</td>
#       <td>1832</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{FAVC=yes,SCC=no}</td>
#       <td>0.856466</td>
#       <td>1808</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{SCC=no,SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{FAVC=yes}</td>
#       <td>0.883941</td>
#       <td>1866</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>0.836097</td>
#       <td>1765</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>0.817622</td>
#       <td>1726</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.9)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{SCC=no,SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.9)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{SCC=no,SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.95)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.95)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>2015</td>
#     </tr>
#   </

# %% [markdown]
# ### Numerical - numerical associations with Apriori algorithm

# %%
parameters = [
    (0.2, 0.4),
    (0.25, 0.6),
]

dataset_subset_dataframe = dataset_dataframe[NUMERICAL_VARIABLES]
dataset_subset_dataframe = dataset_subset_dataframe.apply(
    lambda dataseries, label: bin_numerical_smartly(data_name=next(label), data=dataseries, bins=10),
    args=(iter(dataset_subset_dataframe.columns), )
)
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
numerical_numerical_apriori = {}

for support, confidence in parameters:
    html_out, df_out = run_apriori_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    numerical_numerical_apriori[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for Apriori run (support: 0.2, confidence: 0.4)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{}</td>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.452392</td>
#       <td>0.452392</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>955</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.591663</td>
#       <td>0.591663</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1249</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.649929</td>
#       <td>0.649929</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1372</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Height=(1.75, 3.0]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.204169</td>
#       <td>0.616595</td>
#       <td>0.331123</td>
#       <td>1.042140</td>
#       <td>431</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{FCVC=(0.999, 2.0]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.220275</td>
#       <td>0.579800</td>
#       <td>0.379915</td>
#       <td>0.979951</td>
#       <td>465</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{FCVC=(0.999, 2.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.245855</td>
#       <td>0.647132</td>
#       <td>0.379915</td>
#       <td>0.995697</td>
#       <td>519</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.212222</td>
#       <td>0.530806</td>
#       <td>0.399811</td>
#       <td>1.173331</td>
#       <td>448</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.212222</td>
#       <td>0.469110</td>
#       <td>0.452392</td>
#       <td>1.173331</td>
#       <td>448</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.271435</td>
#       <td>0.678910</td>
#       <td>0.399811</td>
#       <td>1.147461</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.271435</td>
#       <td>0.458767</td>
#       <td>0.591663</td>
#       <td>1.147461</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.299384</td>
#       <td>0.748815</td>
#       <td>0.399811</td>
#       <td>1.152149</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.299384</td>
#       <td>0.460641</td>
#       <td>0.649929</td>
#       <td>1.152149</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.291805</td>
#       <td>0.645026</td>
#       <td>0.452392</td>
#       <td>1.090192</td>
#       <td>616</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.291805</td>
#       <td>0.493195</td>
#       <td>0.591663</td>
#       <td>1.090192</td>
#       <td>616</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.315017</td>
#       <td>0.696335</td>
#       <td>0.452392</td>
#       <td>1.071402</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.315017</td>
#       <td>0.484694</td>
#       <td>0.649929</td>
#       <td>1.071402</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.398389</td>
#       <td>0.673339</td>
#       <td>0.591663</td>
#       <td>1.036019</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.398389</td>
#       <td>0.612974</td>
#       <td>0.649929</td>
#       <td>1.036019</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{FCVC=(2.762, 3.0],NCP=(2.961, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.216485</td>
#       <td>0.797557</td>
#       <td>0.271435</td>
#       <td>1.227144</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{Age=(18, 26],FCVC=(2.762, 3.0]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.216485</td>
#       <td>0.723101</td>
#       <td>0.299384</td>
#       <td>1.222151</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{Age=(18, 26],NCP=(2.961, 3.0]}</td>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.216485</td>
#       <td>0.543401</td>
#       <td>0.398389</td>
#       <td>1.359146</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{Height=(1.62, 1.75],NCP=(2.961, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.222170</td>
#       <td>0.761364</td>
#       <td>0.291805</td>
#       <td>1.171457</td>
#       <td>469</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{Age=(18, 26],Height=(1.62, 1.75]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.222170</td>
#       <td>0.705263</td>
#       <td>0.315017</td>
#       <td>1.192002</td>
#       <td>469</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{Age=(18, 26],NCP=(2.961, 3.0]}</td>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.222170</td>
#       <td>0.557669</td>
#       <td>0.398389</td>
#       <td>1.232712</td>
#       <td>469</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for Apriori run (support: 0.25, confidence: 0.6)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.649929</td>
#       <td>0.649929</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1372</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.271435</td>
#       <td>0.678910</td>
#       <td>0.399811</td>
#       <td>1.147461</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.299384</td>
#       <td>0.748815</td>
#       <td>0.399811</td>
#       <td>1.152149</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.291805</td>
#       <td>0.645026</td>
#       <td>0.452392</td>
#       <td>1.090192</td>
#       <td>616</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.315017</td>
#       <td>0.696335</td>
#       <td>0.452392</td>
#       <td>1.071402</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{Age=(18, 26]}</td>
#       <td>0.398389</td>
#       <td>0.673339</td>
#       <td>0.591663</td>
#       <td>1.036019</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.398389</td>
#       <td>0.612974</td>
#       <td>0.649929</td>
#       <td>1.036019</td>
#       <td>841</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Numerical - numerical associations with ECLAT algorithm

# %%
parameters = [
    (0.2, 0.4),
    (0.25, 0.6),
]

dataset_subset_dataframe = dataset_dataframe[NUMERICAL_VARIABLES]
dataset_subset_dataframe = dataset_subset_dataframe.apply(
    lambda dataseries, label: bin_numerical_smartly(data_name=next(label), data=dataseries, bins=10),
    args=(iter(dataset_subset_dataframe.columns), )
)
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
numerical_numerical_eclat = {}

for support, confidence in parameters:
    html_out, df_out = run_eclat_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    numerical_numerical_eclat[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for ECLAT run (support: 0.2)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{Height=(1.75, 3.0],NCP=(2.961, 3.0]}</td>
#       <td>0.204169</td>
#       <td>431</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{Age=(18, 26],FCVC=(0.999, 2.0]}</td>
#       <td>0.245855</td>
#       <td>519</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{FCVC=(0.999, 2.0],NCP=(2.961, 3.0]}</td>
#       <td>0.220275</td>
#       <td>465</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Age=(18, 26],FCVC=(2.762, 3.0],NCP=(2.961, 3.0]}</td>
#       <td>0.216485</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{Age=(18, 26],FCVC=(2.762, 3.0]}</td>
#       <td>0.299384</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{FCVC=(2.762, 3.0],NCP=(2.961, 3.0]}</td>
#       <td>0.271435</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{Height=(1.62, 1.75],FCVC=(2.762, 3.0]}</td>
#       <td>0.212222</td>
#       <td>448</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{Age=(18, 26],Height=(1.62, 1.75],NCP=(2.961, 3.0]}</td>
#       <td>0.222170</td>
#       <td>469</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{Age=(18, 26],Height=(1.62, 1.75]}</td>
#       <td>0.315017</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{Height=(1.62, 1.75],NCP=(2.961, 3.0]}</td>
#       <td>0.291805</td>
#       <td>616</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{Age=(18, 26],NCP=(2.961, 3.0]}</td>
#       <td>0.398389</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{Age=(18, 26]}</td>
#       <td>0.649929</td>
#       <td>1372</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.591663</td>
#       <td>1249</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.452392</td>
#       <td>955</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.399811</td>
#       <td>844</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{FCVC=(0.999, 2.0]}</td>
#       <td>0.379915</td>
#       <td>802</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{Height=(1.75, 3.0]}</td>
#       <td>0.331123</td>
#       <td>699</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{TUE=(-0.001, 0.0801]}</td>
#       <td>0.300332</td>
#       <td>634</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{CH2O=(1.7913, 2.0]}</td>
#       <td>0.276172</td>
#       <td>583</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{Weight=(100, 120]}</td>
#       <td>0.223117</td>
#       <td>471</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{Height=(0, 1.62]}</td>
#       <td>0.216485</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{Weight=(80, 100]}</td>
#       <td>0.213169</td>
#       <td>450</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{TUE=(0.854, 1.0]}</td>
#       <td>0.208432</td>
#       <td>440</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{FAF=(-0.001, 0.00594]}</td>
#       <td>0.200379</td>
#       <td>423</td>
#     </tr>
#   </tbody>
# </table></br><h2>Result for ECLAT run (support: 0.25)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{Age=(18, 26],FCVC=(2.762, 3.0]}</td>
#       <td>0.299384</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{FCVC=(2.762, 3.0],NCP=(2.961, 3.0]}</td>
#       <td>0.271435</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{Age=(18, 26],Height=(1.62, 1.75]}</td>
#       <td>0.315017</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Height=(1.62, 1.75],NCP=(2.961, 3.0]}</td>
#       <td>0.291805</td>
#       <td>616</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{Age=(18, 26],NCP=(2.961, 3.0]}</td>
#       <td>0.398389</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{Age=(18, 26]}</td>
#       <td>0.649929</td>
#       <td>1372</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>0.591663</td>
#       <td>1249</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>0.452392</td>
#       <td>955</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{FCVC=(2.762, 3.0]}</td>
#       <td>0.399811</td>
#       <td>844</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{FCVC=(0.999, 2.0]}</td>
#       <td>0.379915</td>
#       <td>802</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{Height=(1.75, 3.0]}</td>
#       <td>0.331123</td>
#       <td>699</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{TUE=(-0.001, 0.0801]}</td>
#       <td>0.300332</td>
#       <td>634</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{CH2O=(1.7913, 2.0]}</td>
#       <td>0.276172</td>
#       <td>583</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Categorical + numerical - categorical + numerical associations with Apriori algorithm

# %%
parameters = [
    (0.4, 0.9),
]

dataset_subset_dataframe = dataset_dataframe[ALL_VARIABLES]
dataset_subset_dataframe = dataset_subset_dataframe.apply(
    lambda dataseries, label: bin_numerical_smartly(data_name=next(label), data=dataseries, bins=10),
    args=(iter(dataset_subset_dataframe.columns), )
)
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
catnum_catnum_apriori = {}

for support, confidence in parameters:
    html_out, df_out = run_apriori_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    catnum_catnum_apriori[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for Apriori run (support: 0.4, confidence: 0.9)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{}</td>
#       <td>{SCC=no}</td>
#       <td>0.954524</td>
#       <td>0.954524</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.979157</td>
#       <td>0.979157</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>2067</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{SCC=no}</td>
#       <td>0.438655</td>
#       <td>0.969634</td>
#       <td>0.452392</td>
#       <td>1.015829</td>
#       <td>926</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Height=(1.62, 1.75]}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.444339</td>
#       <td>0.982199</td>
#       <td>0.452392</td>
#       <td>1.003107</td>
#       <td>938</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{Gender=Female}</td>
#       <td>{SCC=no}</td>
#       <td>0.460919</td>
#       <td>0.932886</td>
#       <td>0.494079</td>
#       <td>0.977331</td>
#       <td>973</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{Gender=Female}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.486973</td>
#       <td>0.985618</td>
#       <td>0.494079</td>
#       <td>1.006599</td>
#       <td>1028</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{Gender=Male}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.457603</td>
#       <td>0.904494</td>
#       <td>0.505921</td>
#       <td>1.023252</td>
#       <td>966</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{Gender=Male}</td>
#       <td>{SCC=no}</td>
#       <td>0.493605</td>
#       <td>0.975655</td>
#       <td>0.505921</td>
#       <td>1.022138</td>
#       <td>1042</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{Gender=Male}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.492184</td>
#       <td>0.972846</td>
#       <td>0.505921</td>
#       <td>0.993555</td>
#       <td>1039</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{SCC=no}</td>
#       <td>0.565135</td>
#       <td>0.955164</td>
#       <td>0.591663</td>
#       <td>1.000671</td>
#       <td>1193</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{NCP=(2.961, 3.0]}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.576504</td>
#       <td>0.974380</td>
#       <td>0.591663</td>
#       <td>0.995121</td>
#       <td>1217</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>0.598295</td>
#       <td>0.920554</td>
#       <td>0.649929</td>
#       <td>1.229930</td>
#       <td>1263</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{SCC=no}</td>
#       <td>0.621980</td>
#       <td>0.956997</td>
#       <td>0.649929</td>
#       <td>1.002591</td>
#       <td>1313</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{Age=(18, 26]}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.639507</td>
#       <td>0.983965</td>
#       <td>0.649929</td>
#       <td>1.004911</td>
#       <td>1350</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{CALC=Sometimes}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.607769</td>
#       <td>0.915774</td>
#       <td>0.663667</td>
#       <td>1.036013</td>
#       <td>1283</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{CALC=Sometimes}</td>
#       <td>{SCC=no}</td>
#       <td>0.637613</td>
#       <td>0.960742</td>
#       <td>0.663667</td>
#       <td>1.006515</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{CALC=Sometimes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.648982</td>
#       <td>0.977873</td>
#       <td>0.663667</td>
#       <td>0.998689</td>
#       <td>1370</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>{SCC=no}</td>
#       <td>0.713406</td>
#       <td>0.953165</td>
#       <td>0.748460</td>
#       <td>0.998576</td>
#       <td>1506</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{MTRANS=Public_Transportation}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.734249</td>
#       <td>0.981013</td>
#       <td>0.748460</td>
#       <td>1.001895</td>
#       <td>1550</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.748460</td>
#       <td>0.915411</td>
#       <td>0.817622</td>
#       <td>1.035602</td>
#       <td>1580</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{SCC=no}</td>
#       <td>0.795358</td>
#       <td>0.972769</td>
#       <td>0.817622</td>
#       <td>1.019115</td>
#       <td>1679</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{family_history_with_overweight=yes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.799621</td>
#       <td>0.977984</td>
#       <td>0.817622</td>
#       <td>0.998802</td>
#       <td>1688</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{FAVC=yes}</td>
#       <td>0.761724</td>
#       <td>0.911048</td>
#       <td>0.836097</td>
#       <td>1.030666</td>
#       <td>1608</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{SCC=no}</td>
#       <td>0.810516</td>
#       <td>0.969405</td>
#       <td>0.836097</td>
#       <td>1.015590</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>{CAEC=Sometimes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.821412</td>
#       <td>0.982436</td>
#       <td>0.836097</td>
#       <td>1.003349</td>
#       <td>1734</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>{FAVC=yes}</td>
#       <td>{SCC=no}</td>
#       <td>0.856466</td>
#       <td>0.968917</td>
#       <td>0.883941</td>
#       <td>1.015079</td>
#       <td>1808</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>{FAVC=yes}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.867835</td>
#       <td>0.981779</td>
#       <td>0.883941</td>
#       <td>1.002678</td>
#       <td>1832</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>{SCC=no}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.936049</td>
#       <td>0.980645</td>
#       <td>0.954524</td>
#       <td>1.001520</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>{SMOKE=no}</td>
#       <td>{SCC=no}</td>
#       <td>0.936049</td>
#       <td>0.955975</td>
#       <td>0.979157</td>
#       <td>1.001520</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>{Height=(1.62, 1.75],SCC=no}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.431549</td>
#       <td>0.983801</td>
#       <td>0.438655</td>
#       <td>1.004743</td>
#       <td>911</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>{Height=(1.62, 1.75],SMOKE=no}</td>
#       <td>{SCC=no}</td>
#       <td>0.431549</td>
#       <td>0.971215</td>
#       <td>0.444339</td>
#       <td>1.017487</td>
#       <td>911</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>{MTRANS=Public_Transportation,Gender=Female}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.400284</td>
#       <td>0.989461</td>
#       <td>0.404548</td>
#       <td>1.010524</td>
#       <td>845</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>{FAVC=yes,Gender=Female}</td>
#       <td>{SCC=no}</td>
#       <td>0.405969</td>
#       <td>0.952222</td>
#       <td>0.426338</td>
#       <td>0.997589</td>
#       <td>857</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>{FAVC=yes,Gender=Female}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.421601</td>
#       <td>0.988889</td>
#       <td>0.426338</td>
#       <td>1.009939</td>
#       <td>890</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>{SCC=no,Gender=Female}</td>
#       <td>{SMOKE=no}</td>
#       <td>0.455234</td>
#       <td>0.987667</td>
#       <td>0.460919</td>
#       <td>1.008691</td>
#       <td>961</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>{Gender=Female,SMOKE=no}</td>
#       <td>{SCC=no}</td>
#       <td>0.455234</td>
#       <td>0.934825</td>
#       <td>0.486973</td>
#       <td>0.979362</td>

# %% [markdown]
# ### Categorical + numerical - categorical + numerical associations with ECLAT algorithm

# %%
parameters = [
    (0.4, 0.9),
]

dataset_subset_dataframe = dataset_dataframe[ALL_VARIABLES]
dataset_subset_dataframe = dataset_subset_dataframe.apply(
    lambda dataseries, label: bin_numerical_smartly(data_name=next(label), data=dataseries, bins=10),
    args=(iter(dataset_subset_dataframe.columns), )
)
transactions = arules.Transactions.from_df(dataset_subset_dataframe)
result_html = ""
catnum_catnum_eclat = {}

for support, confidence in parameters:
    html_out, df_out = run_eclat_build_html(
        transactions=transactions, support=support, confidence=confidence
    )
    result_html += html_out
    catnum_catnum_eclat[(support, confidence)] = df_out

HTML(result_html)
# Out:
# <h2>Result for ECLAT run (support: 0.4)</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>{Height=(1.62, 1.75],SCC=no,SMOKE=no}</td>
#       <td>0.431549</td>
#       <td>911</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>{Height=(1.62, 1.75],SMOKE=no}</td>
#       <td>0.444339</td>
#       <td>938</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>{Height=(1.62, 1.75],SCC=no}</td>
#       <td>0.438655</td>
#       <td>926</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>{Height=(1.62, 1.75],FAVC=yes}</td>
#       <td>0.402653</td>
#       <td>850</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{MTRANS=Public_Transportation,Gender=Female,SMOKE=no}</td>
#       <td>0.400284</td>
#       <td>845</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{FAVC=yes,SCC=no,Gender=Female,SMOKE=no}</td>
#       <td>0.401705</td>
#       <td>848</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{FAVC=yes,Gender=Female,SMOKE=no}</td>
#       <td>0.421601</td>
#       <td>890</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>{FAVC=yes,SCC=no,Gender=Female}</td>
#       <td>0.405969</td>
#       <td>857</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>{SCC=no,Gender=Female,SMOKE=no}</td>
#       <td>0.455234</td>
#       <td>961</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>{Gender=Female,SMOKE=no}</td>
#       <td>0.486973</td>
#       <td>1028</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>{SCC=no,Gender=Female}</td>
#       <td>0.460919</td>
#       <td>973</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>{FAVC=yes,Gender=Female}</td>
#       <td>0.426338</td>
#       <td>900</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>{MTRANS=Public_Transportation,Gender=Female}</td>
#       <td>0.404548</td>
#       <td>854</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>{SCC=no,Gender=Male,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.414969</td>
#       <td>876</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>{Gender=Male,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.422075</td>
#       <td>891</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>{SCC=no,Gender=Male,family_history_with_overweight=yes}</td>
#       <td>0.425391</td>
#       <td>898</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>{FAVC=yes,Gender=Male,family_history_with_overweight=yes}</td>
#       <td>0.402653</td>
#       <td>850</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>{CAEC=Sometimes,SCC=no,Gender=Male,SMOKE=no}</td>
#       <td>0.420654</td>
#       <td>888</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>{CAEC=Sometimes,Gender=Male,SMOKE=no}</td>
#       <td>0.425865</td>
#       <td>899</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>{CAEC=Sometimes,SCC=no,Gender=Male}</td>
#       <td>0.431075</td>
#       <td>910</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>{FAVC=yes,CAEC=Sometimes,Gender=Male}</td>
#       <td>0.400758</td>
#       <td>846</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>{FAVC=yes,SCC=no,Gender=Male,SMOKE=no}</td>
#       <td>0.440076</td>
#       <td>929</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>{FAVC=yes,Gender=Male,SMOKE=no}</td>
#       <td>0.446234</td>
#       <td>942</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>{FAVC=yes,SCC=no,Gender=Male}</td>
#       <td>0.450497</td>
#       <td>951</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>{SCC=no,Gender=Male,SMOKE=no}</td>
#       <td>0.480815</td>
#       <td>1015</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>{Gender=Male,SMOKE=no}</td>
#       <td>0.492184</td>
#       <td>1039</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>{SCC=no,Gender=Male}</td>
#       <td>0.493605</td>
#       <td>1042</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>{FAVC=yes,Gender=Male}</td>
#       <td>0.457603</td>
#       <td>966</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>{CAEC=Sometimes,Gender=Male}</td>
#       <td>0.436286</td>
#       <td>921</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>{Gender=Male,family_history_with_overweight=yes}</td>
#       <td>0.433444</td>
#       <td>915</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>{NCP=(2.961, 3.0],CALC=Sometimes,SCC=no,SMOKE=no}</td>
#       <td>0.410706</td>
#       <td>867</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>{NCP=(2.961, 3.0],CALC=Sometimes,SMOKE=no}</td>
#       <td>0.424443</td>
#       <td>896</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>{NCP=(2.961, 3.0],CALC=Sometimes,SCC=no}</td>
#       <td>0.421127</td>
#       <td>889</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CALC=Sometimes}</td>
#       <td>0.401232</td>
#       <td>847</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>{NCP=(2.961, 3.0],SCC=no,MTRANS=Public_Transportation,SMOKE=no}</td>
#       <td>0.420654</td>
#       <td>888</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>{NCP=(2.961, 3.0],MTRANS=Public_Transportation,SMOKE=no}</td>
#       <td>0.438655</td>
#       <td>926</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>{NCP=(2.961, 3.0],SCC=no,MTRANS=Public_Transportation}</td>
#       <td>0.429654</td>
#       <td>907</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,MTRANS=Public_Transportation}</td>
#       <td>0.406916</td>
#       <td>859</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CAEC=Sometimes,SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.414969</td>
#       <td>876</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CAEC=Sometimes,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.416390</td>
#       <td>879</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CAEC=Sometimes,SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.422549</td>
#       <td>892</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>{NCP=(2.961, 3.0],CAEC=Sometimes,SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.439602</td>
#       <td>928</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>{NCP=(2.961, 3.0],CAEC=Sometimes,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.442444</td>
#       <td>934</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>{NCP=(2.961, 3.0],CAEC=Sometimes,SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.449076</td>
#       <td>948</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CAEC=Sometimes,family_history_with_overweight=yes}</td>
#       <td>0.423970</td>
#       <td>895</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.452866</td>
#       <td>956</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.458077</td>
#       <td>967</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.461866</td>
#       <td>975</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>{NCP=(2.961, 3.0],SCC=no,family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.484131</td>
#       <td>1022</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>{NCP=(2.961, 3.0],family_history_with_overweight=yes,SMOKE=no}</td>
#       <td>0.494552</td>
#       <td>1044</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>{NCP=(2.961, 3.0],SCC=no,family_history_with_overweight=yes}</td>
#       <td>0.495500</td>
#       <td>1046</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,family_history_with_overweight=yes}</td>
#       <td>0.468025</td>
#       <td>988</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>{NCP=(2.961, 3.0],CAEC=Sometimes,family_history_with_overweight=yes}</td>
#       <td>0.452866</td>
#       <td>956</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>{NCP=(2.961, 3.0],FAVC=yes,CAEC=Sometimes

# %% [markdown]
# ### Utils

# %%
in_data = categorical_categorical_apriori[(0.8, 0.8)]

def preprocess_str(arg_str: str) -> str:
    arg_str = list(arg_str)
    status = 0
    for it in range(len(arg_str)):
        if arg_str[it] == "," and status == 0:
            arg_str[it] = ";"
        if arg_str[it] in ["(", "["]:
            status += 1
        if arg_str[it] in [")", "]"]:
            status -= 1
    return "".join(arg_str)

def get_assoc(assoc: str) -> list[tuple[str, str]]:
    return [tuple(part.split("=")) for part in list(filter(lambda x: x != "", preprocess_str(assoc[1:-1]).split(";")))]

def distill_dataframe(arg_data: pd.DataFrame) -> pd.DataFrame:
    rules = {
        "LHS": [],
        "RHS": [],
        "support": [],
        "confidence": [],
        "coverage": [],
        "lift": [],
        "count": []
    }

    for it in range(0, len(arg_data)):
        lh_rule = get_assoc(arg_data["LHS"][it])
        rh_rule = get_assoc(arg_data["RHS"][it])

        if len(lh_rule) == 0 or len(rh_rule) == 0:
            continue

        rules["LHS"].append(lh_rule)
        rules["RHS"].append(rh_rule)
        rules["support"].append(arg_data["support"][it])
        rules["confidence"].append(arg_data["confidence"][it])
        rules["coverage"].append(arg_data["coverage"][it])
        rules["lift"].append(arg_data["lift"][it])
        rules["count"].append(arg_data["count"][it])


    return pd.DataFrame(rules).sort_values("confidence", ascending=False).reset_index(drop=True)[:10]


def get_associations_with_label(assoc_data: pd.DataFrame) -> pd.DataFrame:
    rules = {
        "LHS": [],
        "RHS": [],
        "support": [],
        "confidence": [],
        "coverage": [],
        "lift": [],
        "count": []
    }

    for it in range(len(assoc_data)):
        lh_rule = assoc_data["LHS"][it]
        rh_rule = assoc_data["RHS"][it]

        if len(rh_rule) != 1 or rh_rule[0][0] != LABEL_VARIABLE:
            continue

        rules["LHS"].append(lh_rule)
        rules["RHS"].append(rh_rule)
        rules["support"].append(assoc_data["support"][it])
        rules["confidence"].append(assoc_data["confidence"][it])
        rules["coverage"].append(assoc_data["coverage"][it])
        rules["lift"].append(assoc_data["lift"][it])
        rules["count"].append(assoc_data["count"][it])

    return pd.DataFrame(rules)

# %% [markdown]
# ### Categorical - Categorical top rules with Apriori algorithm

# %%
distyled_categorical_categorical_apriori = distill_dataframe(categorical_categorical_apriori[(0.7, 0.4)])

HTML(data_frame_to_html("Categorical - Categorical top rules with Apriori algorithm", distyled_categorical_categorical_apriori))
# Out:
# <h2>Categorical - Categorical top rules with Apriori algorithm</h2></br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[(FAVC, yes), (CAEC, Sometimes)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.750829</td>
#       <td>0.985697</td>
#       <td>0.761724</td>
#       <td>1.006679</td>
#       <td>1585</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[(FAVC, yes), (CAEC, Sometimes), (SCC, no)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.731407</td>
#       <td>0.985322</td>
#       <td>0.742302</td>
#       <td>1.006297</td>
#       <td>1544</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[(CAEC, Sometimes), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.708195</td>
#       <td>0.984848</td>
#       <td>0.719090</td>
#       <td>1.031769</td>
#       <td>1495</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(CAEC, Sometimes), (family_history_with_overweight, yes)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.720512</td>
#       <td>0.983829</td>
#       <td>0.732354</td>
#       <td>1.030701</td>
#       <td>1521</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[(FAVC, yes), (SCC, no), (family_history_with_overweight, yes)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.721459</td>
#       <td>0.983215</td>
#       <td>0.733775</td>
#       <td>1.004145</td>
#       <td>1523</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[(CAEC, Sometimes), (SCC, no)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.796779</td>
#       <td>0.983051</td>
#       <td>0.810516</td>
#       <td>1.003977</td>
#       <td>1682</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[(CAEC, Sometimes), (SCC, no), (family_history_with_overweight, yes)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.708195</td>
#       <td>0.982906</td>
#       <td>0.720512</td>
#       <td>1.003829</td>
#       <td>1495</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[(FAVC, yes), (SCC, no)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.841781</td>
#       <td>0.982854</td>
#       <td>0.856466</td>
#       <td>1.003776</td>
#       <td>1777</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[(SCC, no), (MTRANS, Public_Transportation)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.701090</td>
#       <td>0.982736</td>
#       <td>0.713406</td>
#       <td>1.003655</td>
#       <td>1480</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(CAEC, Sometimes)]</td>
#       <td>[(SMOKE, no)]</td>
#       <td>0.821412</td>
#       <td>0.982436</td>
#       <td>0.836097</td>
#       <td>1.003349</td>
#       <td>1734</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Numerical - Numerical top rules with Apriori algorithm

# %%
distyled_numerical_numerical_apriori = distill_dataframe(numerical_numerical_apriori[(0.2, 0.4)])

HTML(data_frame_to_html("Numerical - Numerical top rules with Apriori algorithm", distyled_numerical_numerical_apriori))
# Out:
# <h2>Numerical - Numerical top rules with Apriori algorithm</h2></br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[(FCVC, (2.762, 3.0]), (NCP, (2.961, 3.0])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.216485</td>
#       <td>0.797557</td>
#       <td>0.271435</td>
#       <td>1.227144</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[(Height, (1.62, 1.75]), (NCP, (2.961, 3.0])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.222170</td>
#       <td>0.761364</td>
#       <td>0.291805</td>
#       <td>1.171457</td>
#       <td>469</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[(FCVC, (2.762, 3.0])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.299384</td>
#       <td>0.748815</td>
#       <td>0.399811</td>
#       <td>1.152149</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(Age, (18, 26]), (FCVC, (2.762, 3.0])]</td>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>0.216485</td>
#       <td>0.723101</td>
#       <td>0.299384</td>
#       <td>1.222151</td>
#       <td>457</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[(Age, (18, 26]), (Height, (1.62, 1.75])]</td>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>0.222170</td>
#       <td>0.705263</td>
#       <td>0.315017</td>
#       <td>1.192002</td>
#       <td>469</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[(Height, (1.62, 1.75])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.315017</td>
#       <td>0.696335</td>
#       <td>0.452392</td>
#       <td>1.071402</td>
#       <td>665</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[(FCVC, (2.762, 3.0])]</td>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>0.271435</td>
#       <td>0.678910</td>
#       <td>0.399811</td>
#       <td>1.147461</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.398389</td>
#       <td>0.673339</td>
#       <td>0.591663</td>
#       <td>1.036019</td>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[(FCVC, (0.999, 2.0])]</td>
#       <td>[(Age, (18, 26])]</td>
#       <td>0.245855</td>
#       <td>0.647132</td>
#       <td>0.379915</td>
#       <td>0.995697</td>
#       <td>519</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(Height, (1.62, 1.75])]</td>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>0.291805</td>
#       <td>0.645026</td>
#       <td>0.452392</td>
#       <td>1.090192</td>
#       <td>616</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Categorical + Numerical - Categorical + Numerical top rules with Apriori algorithm

# %%
distyled_catnum_catnum_apriori = distill_dataframe(catnum_catnum_apriori[(0.4, 0.9)])

HTML(data_frame_to_html("Categorical + Numerical - Categorical + Numerical top rules with Apriori algorithm", distyled_catnum_catnum_apriori))
# Out:
# <h2>Categorical + Numerical - Categorical + Numerical top rules with Apriori algorithm</h2></br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (CAEC, Sometimes), (family_history_with_overweight, yes)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.428233</td>
#       <td>0.998895</td>
#       <td>0.428707</td>
#       <td>1.046485</td>
#       <td>904</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (CAEC, Sometimes), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.425391</td>
#       <td>0.998888</td>
#       <td>0.425865</td>
#       <td>1.046477</td>
#       <td>898</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (CAEC, Sometimes), (MTRANS, Public_Transportation), (family_history_with_overweight, yes)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.406442</td>
#       <td>0.998836</td>
#       <td>0.406916</td>
#       <td>1.046423</td>
#       <td>858</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (CAEC, Sometimes), (MTRANS, Public_Transportation), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.403600</td>
#       <td>0.998828</td>
#       <td>0.404074</td>
#       <td>1.046414</td>
#       <td>852</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[(NCP, (2.961, 3.0]), (FAVC, yes), (CAEC, Sometimes), (family_history_with_overweight, yes)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.422549</td>
#       <td>0.996648</td>
#       <td>0.423970</td>
#       <td>1.044131</td>
#       <td>892</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[(NCP, (2.961, 3.0]), (FAVC, yes), (CAEC, Sometimes), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.414969</td>
#       <td>0.996587</td>
#       <td>0.416390</td>
#       <td>1.044067</td>
#       <td>876</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (MTRANS, Public_Transportation), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.444339</td>
#       <td>0.995754</td>
#       <td>0.446234</td>
#       <td>1.043194</td>
#       <td>938</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[(Age, (18, 26]), (CAEC, Sometimes), (MTRANS, Public_Transportation), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.431075</td>
#       <td>0.994536</td>
#       <td>0.433444</td>
#       <td>1.041918</td>
#       <td>910</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[(Age, (18, 26]), (CAEC, Sometimes), (family_history_with_overweight, yes), (SMOKE, no)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.459024</td>
#       <td>0.993846</td>
#       <td>0.461866</td>
#       <td>1.041196</td>
#       <td>969</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(Age, (18, 26]), (FAVC, yes), (MTRANS, Public_Transportation), (family_history_with_overweight, yes)]</td>
#       <td>[(SCC, no)]</td>
#       <td>0.448129</td>
#       <td>0.993697</td>
#       <td>0.450971</td>
#       <td>1.041040</td>
#       <td>946</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Categorical - Label associations with Apriori algorithm

# %%
parameters = [
    (0.05, 0.05)
]

result = ""
catlabel_df = None

for cat in CATEGORICAL_VARIABLES_NO_LABEL:

    dataset_subset_dataframe = dataset_dataframe[[LABEL_VARIABLE, cat]]
    transactions = arules.Transactions.from_df(dataset_subset_dataframe)

    for support, confidence in parameters:
        html_out, df_out =  run_apriori_build_html(
            transactions=transactions, support=support, confidence=confidence
        )

        df_out = get_associations_with_label(distill_dataframe(df_out))

        if catlabel_df is not None:
            catlabel_df = pd.concat([catlabel_df, df_out])
        else:
            catlabel_df = df_out

catlabel_df = catlabel_df.sort_values("confidence", ascending=False).reset_index(drop=True)

HTML(data_frame_to_html("Categorical to Label Top Rules", catlabel_df))
# Out:
# <h2>Categorical to Label Top Rules</h2></br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[(CAEC, Frequently)]</td>
#       <td>[(NObeyesdad, Insufficient_Weight)]</td>
#       <td>0.057319</td>
#       <td>0.500000</td>
#       <td>0.114638</td>
#       <td>3.880515</td>
#       <td>121.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[(family_history_with_overweight, no)]</td>
#       <td>[(NObeyesdad, Insufficient_Weight)]</td>
#       <td>0.069162</td>
#       <td>0.379221</td>
#       <td>0.182378</td>
#       <td>2.943144</td>
#       <td>146.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[(MTRANS, Automobile)]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.052108</td>
#       <td>0.240700</td>
#       <td>0.216485</td>
#       <td>1.447630</td>
#       <td>110.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(MTRANS, Public_Transportation)]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153008</td>
#       <td>0.204430</td>
#       <td>0.748460</td>
#       <td>1.331952</td>
#       <td>323.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[(CAEC, Sometimes)]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.160114</td>
#       <td>0.191501</td>
#       <td>0.836097</td>
#       <td>1.151736</td>
#       <td>338.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[(FAVC, yes)]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.161061</td>
#       <td>0.182208</td>
#       <td>0.883941</td>
#       <td>1.095843</td>
#       <td>340.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[(SCC, no)]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.165324</td>
#       <td>0.173201</td>
#       <td>0.954524</td>
#       <td>1.041673</td>
#       <td>349.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[(FAVC, yes)]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153008</td>
#       <td>0.173098</td>
#       <td>0.883941</td>
#       <td>1.127805</td>
#       <td>323.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[(SMOKE, no)]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.163430</td>
#       <td>0.166909</td>
#       <td>0.979157</td>
#       <td>1.003829</td>
#       <td>345.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(SCC, no)]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153482</td>
#       <td>0.160794</td>
#       <td>0.954524</td>
#       <td>1.047643</td>
#       <td>324.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[(SMOKE, no)]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153008</td>
#       <td>0.156265</td>
#       <td>0.979157</td>
#       <td>1.018135</td>
#       <td>323.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[(FAVC, yes)]</td>
#       <td>[(NObeyesdad, Obesity_Type_II)]</td>
#       <td>0.137376</td>
#       <td>0.155413</td>
#       <td>0.883941</td>
#       <td>1.104633</td>
#       <td>290.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[(SCC, no)]</td>
#       <td>[(NObeyesdad, Obesity_Type_II)]</td>
#       <td>0.140218</td>
#       <td>0.146898</td>
#       <td>0.954524</td>
#       <td>1.044115</td>
#       <td>296.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[(SMOKE, no)]</td>
#       <td>[(NObeyesdad, Overweight_Level_I)]</td>
#       <td>0.135955</td>
#       <td>0.138849</td>
#       <td>0.979157</td>
#       <td>1.010722</td>
#       <td>287.0</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Numerical - Label associations with Apriori algorithm

# %%
parameters = [
    (0.05, 0.05)
]

result = ""
numlabel_df = None

for num in NUMERICAL_VARIABLES:

    dataset_subset_dataframe = dataset_dataframe[[LABEL_VARIABLE, num]]

    dataset_subset_dataframe = dataset_subset_dataframe.apply(
        lambda dataseries, label: bin_numerical_smartly(data_name=next(label), data=dataseries, bins=10),
        args=(iter(dataset_subset_dataframe.columns), )
    )

    transactions = arules.Transactions.from_df(dataset_subset_dataframe)

    result = ""

    for support, confidence in parameters:
        html_out, df_out =  run_apriori_build_html(
            transactions=transactions, support=support, confidence=confidence
        )

        df_out = get_associations_with_label(distill_dataframe(df_out))

        if numlabel_df is not None:
            numlabel_df = pd.concat([numlabel_df, df_out])
        else:
            numlabel_df = df_out

numlabel_df = numlabel_df.sort_values("confidence", ascending=False).reset_index(drop=True)

HTML(data_frame_to_html("Numerical to Label Top Rules", numlabel_df))
# Out:
# <h2>Numerical to Label Top Rules</h2></br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LHS</th>
#       <th>RHS</th>
#       <th>support</th>
#       <th>confidence</th>
#       <th>coverage</th>
#       <th>lift</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[(Weight, (0, 55])]</td>
#       <td>[(NObeyesdad, Insufficient_Weight)]</td>
#       <td>0.102321</td>
#       <td>0.739726</td>
#       <td>0.138323</td>
#       <td>5.741035</td>
#       <td>216.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[(Weight, (120, 400])]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.068214</td>
#       <td>0.587755</td>
#       <td>0.116059</td>
#       <td>3.829478</td>
#       <td>144.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[(NCP, (3.105, 4.0])]</td>
#       <td>[(NObeyesdad, Insufficient_Weight)]</td>
#       <td>0.050213</td>
#       <td>0.502370</td>
#       <td>0.099953</td>
#       <td>3.898906</td>
#       <td>106.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(Weight, (55, 70])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.076741</td>
#       <td>0.445055</td>
#       <td>0.172430</td>
#       <td>3.273557</td>
#       <td>162.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[(Age, (26, 36])]</td>
#       <td>[(NObeyesdad, Obesity_Type_II)]</td>
#       <td>0.065846</td>
#       <td>0.406433</td>
#       <td>0.162009</td>
#       <td>2.888820</td>
#       <td>139.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[(FCVC, (2.762, 3.0])]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153482</td>
#       <td>0.383886</td>
#       <td>0.399811</td>
#       <td>2.501185</td>
#       <td>324.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[(Height, (1.75, 3.0])]</td>
#       <td>[(NObeyesdad, Obesity_Type_II)]</td>
#       <td>0.102795</td>
#       <td>0.310443</td>
#       <td>0.331123</td>
#       <td>2.206553</td>
#       <td>217.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[(CH2O, (1.7913, 2.0])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.077688</td>
#       <td>0.281304</td>
#       <td>0.276172</td>
#       <td>2.069101</td>
#       <td>164.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[(TUE, (0.854, 1.0])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.057793</td>
#       <td>0.277273</td>
#       <td>0.208432</td>
#       <td>2.039452</td>
#       <td>122.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153482</td>
#       <td>0.259408</td>
#       <td>0.591663</td>
#       <td>1.690152</td>
#       <td>324.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[(FCVC, (0.999, 2.0])]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.094268</td>
#       <td>0.248130</td>
#       <td>0.379915</td>
#       <td>1.492313</td>
#       <td>199.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[(Height, (1.62, 1.75])]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.109427</td>
#       <td>0.241885</td>
#       <td>0.452392</td>
#       <td>1.575984</td>
#       <td>231.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[(Age, (18, 26])]</td>
#       <td>[(NObeyesdad, Obesity_Type_III)]</td>
#       <td>0.153008</td>
#       <td>0.235423</td>
#       <td>0.649929</td>
#       <td>1.533881</td>
#       <td>323.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[(FCVC, (0.999, 2.0])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.081952</td>
#       <td>0.215711</td>
#       <td>0.379915</td>
#       <td>1.586639</td>
#       <td>173.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[(CH2O, (1.7913, 2.0])]</td>
#       <td>[(NObeyesdad, Overweight_Level_II)]</td>
#       <td>0.057319</td>
#       <td>0.207547</td>
#       <td>0.276172</td>
#       <td>1.510800</td>
#       <td>121.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[(TUE, (-0.001, 0.0801])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.061108</td>
#       <td>0.203470</td>
#       <td>0.300332</td>
#       <td>1.496604</td>
#       <td>129.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[(TUE, (-0.001, 0.0801])]</td>
#       <td>[(NObeyesdad, Obesity_Type_I)]</td>
#       <td>0.061108</td>
#       <td>0.203470</td>
#       <td>0.300332</td>
#       <td>1.223719</td>
#       <td>129.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[(Height, (1.62, 1.75])]</td>
#       <td>[(NObeyesdad, Overweight_Level_II)]</td>
#       <td>0.081478</td>
#       <td>0.180105</td>
#       <td>0.452392</td>
#       <td>1.311038</td>
#       <td>172.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[(TUE, (-0.001, 0.0801])]</td>
#       <td>[(NObeyesdad, Obesity_Type_II)]</td>
#       <td>0.053529</td>
#       <td>0.178233</td>
#       <td>0.300332</td>
#       <td>1.266838</td>
#       <td>113.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[(TUE, (-0.001, 0.0801])]</td>
#       <td>[(NObeyesdad, Overweight_Level_I)]</td>
#       <td>0.052582</td>
#       <td>0.175079</td>
#       <td>0.300332</td>
#       <td>1.274453</td>
#       <td>111.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[(NCP, (2.961, 3.0])]</td>
#       <td>[(NObeyesdad, Normal_Weight)]</td>
#       <td>0.097584</td>
#       <td>0.164932</td>
#       <td>0.591663</td>
#       <td>1.213141</td>
#       <td>206.0</td>
#     </tr>
#   </tbody>
# </table></br>

# %% [markdown]
# ### Visualisations
#
# ### Here we visualise the rules we found using the algorithms above.

# %%
def get_single_association(arg_data: pd.DataFrame) -> pd.DataFrame:
    arg_data = copy.deepcopy(arg_data)

    rules = {
        "LHS": [],
        "RHS": [],
        "support": [],
        "confidence": [],
        "coverage": [],
        "lift": [],
        "count": []
    }

    for it in range(0, len(arg_data)):
        lh_rule = arg_data["LHS"][it]
        rh_rule = arg_data["RHS"][it]

        if len(lh_rule) != 1 or len(rh_rule) != 1:
            continue

        rules["LHS"].append(lh_rule[0])
        rules["RHS"].append(rh_rule[0])
        rules["support"].append(arg_data["support"][it])
        rules["confidence"].append(arg_data["confidence"][it])
        rules["coverage"].append(arg_data["coverage"][it])
        rules["lift"].append(arg_data["lift"][it])
        rules["count"].append(arg_data["count"][it])

    return pd.DataFrame(rules)


def strip_variables_categories(arg_data: pd.DataFrame) -> pd.DataFrame:
    arg_data = copy.deepcopy(arg_data)
    for it in range(0, len(arg_data)):
        arg_data["LHS"][it] = arg_data["LHS"][it][0]
        arg_data["RHS"][it] = arg_data["RHS"][it][0]
    return arg_data

# %% [markdown]
# ### Categorical - Categorical CatPlot

# %%
categorical_categorical_catplot_df = get_single_association(distyled_categorical_categorical_apriori)


colors=['green','grey','orange']
catscatter(categorical_categorical_catplot_df,'LHS','RHS','confidence', color=colors,ratio=100)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica

# %% [markdown]
# ### Numerical - Numerical CatPlot

# %%
numerical_numerical_catplot_df = get_single_association(distyled_numerical_numerical_apriori)


colors=['green','grey','orange']
catscatter(numerical_numerical_catplot_df,'LHS','RHS','confidence', color=colors,ratio=100)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica

# %% [markdown]
# ### Visualisations
#
# ### Here we visualise the rules we found using the algorithms above.

# %%
catlabel_df_catscat = get_single_association(catlabel_df)


colors=['green','grey','orange']
catscatter(catlabel_df_catscat,'LHS','RHS','confidence', color=colors,ratio=100)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica

# %%
numlabel_df_catscat = get_single_association(numlabel_df)


colors=['green','grey','orange']
catscatter(numlabel_df_catscat,'LHS','RHS','confidence', color=colors,ratio=100)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
